# %% [markdown]
# # OpenAI Responses API Examples

# %%
from openai import OpenAI

# %%
client = OpenAI(
    base_url="http://localhost:8000/v1",
    api_key="no-need"
)

# %% [markdown]
# ## Text input

# %% [markdown]
# ### Non-streaming response

# %%
response = client.responses.create(
  model="mlx-local-model",
  input="Tell me a three sentence bedtime story about a unicorn."
)

print(response)
# Out:
# Response(id='resp_000e7d933b6e41379381f7970b316b56', created_at=1771748881.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[ResponseReasoningItem(id='rs_000e7d933b6e41379381f7970b316b56', summary=[Summary(text='Okay, user wants a three-sentence bedtime story about a unicorn. That\'s a sweet request - probably for a child or someone needing lulling content. \n\nHmm, bedtime stories need to be soothing but magical. Should avoid scary elements since it\'s for sleep. Unicorn tropes are safe: sparkle, gentle nature, dreams. \n\nUser didn\'t specify audience age, so I\'ll aim for universal charm - simple words but vivid imagery. Key is making it feel complete in exactly three sentences. First sentence sets scene, second adds wonder, third resolves peacefully. \n\n*checks structure* \nSentence 1: Establishing calm (moonlight, meadow) \nSentence 2: Unicorn\'s magical action (shimmering horn) \nSentence 3: Emotional payoff (dreams, sleep) \n\nAdded "softly" and "gently" for sensory calmness. Made sure it ends with sleep - that\'s bedtime story gold. Hope they snuggle under covers now.\n', type='summary_text')], type='reasoning', content=[Content(text='Okay, user wants a three-sentence bedtime story about a unicorn. That\'s a sweet request - probably for a child or someone needing lulling content. \n\nHmm, bedtime stories need to be soothing but magical. Should avoid scary elements since it\'s for sleep. Unicorn tropes are safe: sparkle, gentle nature, dreams. \n\nUser didn\'t specify audience age, so I\'ll aim for universal charm - simple words but vivid imagery. Key is making it feel complete in exactly three sentences. First sentence sets scene, second adds wonder, third resolves peacefully. \n\n*checks structure* \nSentence 1: Establishing calm (moonlight, meadow) \nSentence 2: Unicorn\'s magical action (shimmering horn) \nSentence 3: Emotional payoff (dreams, sleep) \n\nAdded "softly" and "gently" for sensory calmness. Made sure it ends with sleep - that\'s bedtime story gold. Hope they snuggle under covers now.\n', type='reasoning_text')], encrypted_content=None, status='completed'), ResponseOutputMessage(id='msg_000e7d933b6e41379381f7970b316b56', content=[ResponseOutputText(annotations=[], text='\n\nUnder the soft glow of the moon, a gentle unicorn drifted through the starlit meadow, her silver mane catching the sleepy light. As she lifted her shimmering horn towards the sky, a sprinkle of gentle stardust fell like cold fireflies, weaving dreams of soft clouds and quiet ponds. With a sigh as warm as moonbeams, the unicorn curled her glittering body into a cozy pile of dandelion fluff, and the whole forest settled into a deep, peaceful sleep.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=None, temperature=1.0, tool_choice='auto', tools=None, top_p=1.0, background=None, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier=None, status='completed', text=None, top_logprobs=None, truncation=None, usage=ResponseUsage(input_tokens=21, input_tokens_details=InputTokensDetails(cached_tokens=0, input_tokens_per_turn=[], cached_tokens_per_turn=[]), output_tokens=300, output_tokens_details=OutputTokensDetails(reasoning_tokens=0, tool_output_tokens=0, output_tokens_per_turn=[], tool_output_tokens_per_turn=[]), total_tokens=321), user=None)

# %% [markdown]
# ### Streaming response

# %%
response = client.responses.create(
  model="mlx-local-model",
  input="Tell me a three sentence bedtime story about a unicorn.",
  stream=True
)

for chunk in response:
  print(chunk)
# Out:
# ResponseCreatedEvent(response=Response(id='resp_05565b3160e54a60897dd6d2daa653c5', created_at=1771748906.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='in_progress', text=None, top_logprobs=None, truncation='disabled', usage=None, user=None), sequence_number=0, type='response.created')
# ResponseInProgressEvent(response=Response(id='resp_05565b3160e54a60897dd6d2daa653c5', created_at=1771748906.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='in_progress', text=None, top_logprobs=None, truncation='disabled', usage=None, user=None), sequence_number=1, type='response.in_progress')
# ResponseOutputItemAddedEvent(item=ResponseReasoningItem(id='rs_05565b3160e54a60897dd6d2daa653c5', summary=[], type='reasoning', content=None, encrypted_content=None, status='in_progress'), output_index=0, sequence_number=2, type='response.output_item.added')
# ResponseReasoningSummaryTextDeltaEvent(delta='Okay,', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=3, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=4, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' user', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=5, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' asked', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=6, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' for', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=7, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=8, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' three-sentence', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=9, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' bedtime', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=10, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' story', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=11, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' about', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=12, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=13, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unicorn.', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=14, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" That's", item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=15, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=16, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' simple', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=17, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' but', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=18, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' specific', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=19, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' request.', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=20, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' \n\nHmm,', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=21, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' they', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=22, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' probably', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=23, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' want', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=24, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' something', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=25, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' soothing', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=26, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=27, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' magical', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=28, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' for', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=29, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=30, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' child—maybe', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=31, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=32, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' parent', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=33, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' or', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=34, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' caregiver', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=35, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' preparing', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=36, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' for', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=37, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' bedtime.', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=38, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' The', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=39, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' three-sentence', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=40, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' limit', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=41, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' suggests', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=42, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' they', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=43, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' value', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=44, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' brevity,', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=45, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' so', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=46, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" I'll", item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=47, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' keep', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=48, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' it', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=49, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' tight', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=50, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' but', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=51, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' vivid.', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=52, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' \n\nI', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=53, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' should', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=54, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' focus', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=55, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' on', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=56, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' warmth', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=57, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=58, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' calmness:', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=59, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' soft', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=60, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' imagery', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=61, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (moonlight,', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=62, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' dandelions),', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=63, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' gentle', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=64, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' sounds', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=65, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' ("hushed', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=66, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' sigh"),', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=67, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=68, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=69, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' peaceful', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=70, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' resolution.', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=71, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' No', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=72, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' conflict—just', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=73, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' tranquility.', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=74, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' \n\n...And', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=75, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' definitely', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=76, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' no', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=77, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' scary', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=78, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' elements!', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=79, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' *adds', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=80, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' glittery', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=81, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' sparkle*', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=82, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' \n\n*checks', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=83, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' length*', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=84, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Yep,', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=85, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' exactly', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=86, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' three', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=87, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' sentences.', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=88, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Hope', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=89, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' it', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=90, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' makes', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=91, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' them', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=92, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' smile', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=93, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' before', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=94, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' sleep.\n', item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=95, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseOutputItemAddedEvent(item=ResponseOutputMessage(id='msg_05565b3160e54a60897dd6d2daa653c5', content=[], role='assistant', status='in_progress', type='message'), output_index=1, sequence_number=96, type='response.output_item.added')
# ResponseContentPartAddedEvent(content_index=0, item_id='msg_05565b3160e54a60897dd6d2daa653c5', output_index=1, part=ResponseOutputText(annotations=[], text='', type='output_text', logprobs=[]), sequence_number=97, type='response.content_part.added')
# ResponseTextDeltaEvent(content_index=0, delta='\n\nUnder', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=98, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=99, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' silver', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=100, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' moonlight,', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=101, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=102, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' shy', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=103, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' unicorn', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=104, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' drifted', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=105, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' through', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=106, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=107, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' meadow,', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=108, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' her', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=109, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' horn', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=110, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' catching', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=111, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=112, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' stars', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=113, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' like', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=114, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' scattered', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=115, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' diamonds.', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=116, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' She', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=117, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' gently', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=118, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' nudged', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=119, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=120, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' sleepy', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=121, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' dandelion', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=122, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' puffball', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=123, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' with', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=124, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' her', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=125, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' nose,', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=126, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' sending', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=127, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=128, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' shower', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=129, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=130, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' soft,', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=131, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' glowing', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=132, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' seeds', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=133, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' dancing', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=134, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' into', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=135, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=136, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' hushed', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=137, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' night', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=138, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' air.', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=139, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' With', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=140, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=141, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' contented', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=142, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' sigh,', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=143, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' she', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=144, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' settled', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=145, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' onto', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=146, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=147, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' cool', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=148, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' grass', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=149, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' as', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=150, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=151, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' last', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=152, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' star', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=153, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' winked', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=154, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' out,', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=155, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' her', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=156, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' magic', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=157, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' weaving', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=158, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=159, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' blanket', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=160, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=161, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' warm,', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=162, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' silent', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=163, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' dreams', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=164, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' over', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=165, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=166, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' world.', item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=167, type='response.output_text.delta')
# ResponseReasoningSummaryTextDoneEvent(item_id='rs_05565b3160e54a60897dd6d2daa653c5', output_index=0, sequence_number=168, summary_index=0, text='Okay, the user asked for a three-sentence bedtime story about a unicorn. That\'s a simple but specific request. \n\nHmm, they probably want something soothing and magical for a child—maybe a parent or caregiver preparing for bedtime. The three-sentence limit suggests they value brevity, so I\'ll keep it tight but vivid. \n\nI should focus on warmth and calmness: soft imagery (moonlight, dandelions), gentle sounds ("hushed sigh"), and a peaceful resolution. No conflict—just tranquility. \n\n...And definitely no scary elements! *adds glittery sparkle* \n\n*checks length* Yep, exactly three sentences. Hope it makes them smile before sleep.\n', type='response.reasoning_summary_text.done')
# ResponseOutputItemDoneEvent(item=ResponseReasoningItem(id='rs_05565b3160e54a60897dd6d2daa653c5', summary=[Summary(text='Okay, the user asked for a three-sentence bedtime story about a unicorn. That\'s a simple but specific request. \n\nHmm, they probably want something soothing and magical for a child—maybe a parent or caregiver preparing for bedtime. The three-sentence limit suggests they value brevity, so I\'ll keep it tight but vivid. \n\nI should focus on warmth and calmness: soft imagery (moonlight, dandelions), gentle sounds ("hushed sigh"), and a peaceful resolution. No conflict—just tranquility. \n\n...And definitely no scary elements! *adds glittery sparkle* \n\n*checks length* Yep, exactly three sentences. Hope it makes them smile before sleep.\n', type='summary_text')], type='reasoning', content=None, encrypted_content=None, status='completed'), output_index=0, sequence_number=169, type='response.output_item.done')
# ResponseTextDoneEvent(content_index=0, item_id='msg_05565b3160e54a60897dd6d2daa653c5', logprobs=[], output_index=1, sequence_number=170, text='\n\nUnder the silver moonlight, a shy unicorn drifted through the meadow, her horn catching the stars like scattered diamonds. She gently nudged a sleepy dandelion puffball with her nose, sending a shower of soft, glowing seeds dancing into the hushed night air. With a contented sigh, she settled onto the cool grass as the last star winked out, her magic weaving a blanket of warm, silent dreams over the world.', type='response.output_text.done')
# ResponseContentPartDoneEvent(content_index=0, item_id='msg_05565b3160e54a60897dd6d2daa653c5', output_index=1, part=ResponseOutputText(annotations=[], text='\n\nUnder the silver moonlight, a shy unicorn drifted through the meadow, her horn catching the stars like scattered diamonds. She gently nudged a sleepy dandelion puffball with her nose, sending a shower of soft, glowing seeds dancing into the hushed night air. With a contented sigh, she settled onto the cool grass as the last star winked out, her magic weaving a blanket of warm, silent dreams over the world.', type='output_text', logprobs=None), sequence_number=171, type='response.content_part.done')
# ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_05565b3160e54a60897dd6d2daa653c5', content=[ResponseOutputText(annotations=[], text='\n\nUnder the silver moonlight, a shy unicorn drifted through the meadow, her horn catching the stars like scattered diamonds. She gently nudged a sleepy dandelion puffball with her nose, sending a shower of soft, glowing seeds dancing into the hushed night air. With a contented sigh, she settled onto the cool grass as the last star winked out, her magic weaving a blanket of warm, silent dreams over the world.', type='output_text', logprobs=None)], role='assistant', status='completed', type='message', summary=[]), output_index=1, sequence_number=172, type='response.output_item.done')
# ResponseCompletedEvent(response=Response(id='resp_05565b3160e54a60897dd6d2daa653c5', created_at=1771748906.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[ResponseReasoningItem(id='rs_05565b3160e54a60897dd6d2daa653c5', summary=[Summary(text='Okay, the user asked for a three-sentence bedtime story about a unicorn. That\'s a simple but specific request. \n\nHmm, they probably want something soothing and magical for a child—maybe a parent or caregiver preparing for bedtime. The three-sentence limit suggests they value brevity, so I\'ll keep it tight but vivid. \n\nI should focus on warmth and calmness: soft imagery (moonlight, dandelions), gentle sounds ("hushed sigh"), and a peaceful resolution. No conflict—just tranquility. \n\n...And definitely no scary elements! *adds glittery sparkle* \n\n*checks length* Yep, exactly three sentences. Hope it makes them smile before sleep.\n', type='summary_text')], type='reasoning', content=None, encrypted_content=None, status='completed'), ResponseOutputMessage(id='msg_05565b3160e54a60897dd6d2daa653c5', content=[ResponseOutputText(annotations=[], text='\n\nUnder the silver moonlight, a shy unicorn drifted through the meadow, her horn catching the stars like scattered diamonds. She gently nudged a sleepy dandelion puffball with her nose, sending a shower of soft, glowing seeds dancing into the hushed night air. With a contented sigh, she settled onto the cool grass as the last star winked out, her magic weaving a blanket of warm, silent dreams over the world.', type='output_text', logprobs=None)], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='completed', text=None, top_logprobs=None, truncation='disabled', usage=ResponseUsage(input_tokens=21, input_tokens_details=InputTokensDetails(cached_tokens=0, input_tokens_per_turn=[], cached_tokens_per_turn=[]), output_tokens=232, output_tokens_details=OutputTokensDetails(reasoning_tokens=0, tool_output_tokens=0, output_tokens_per_turn=[], tool_output_tokens_per_turn=[]), total_tokens=253), user=None), sequence_number=173, type='response.completed')

# %% [markdown]
# ## Image input

# %% [markdown]
# ### Non-streaming response

# %%
response = client.responses.create(
    model="mlx-local-model",
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "what is in this image?"},
                {
                    "type": "input_image",
                    "image_url": "examples/images/password.jpg",
                    "detail": "low"
                }
            ]
        }
    ]
)

print(response)
# Out:
# Response(id='resp_e729e4a81d644db18e01413731637ae3', created_at=1771749057.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[ResponseReasoningItem(id='rs_e729e4a81d644db18e01413731637ae3', summary=[Summary(text='So, let\'s look at the image. It\'s a printed receipt or a Wi-Fi information slip. The top says "Ashley Hotel West Coast" with a line. Then "WiFi Internet Service". Next, details: Username: fppp, Password: aeeu, Traffic: 1 GB, Price: 0.00, Validity: 1w (wait, maybe "Validity" is a typo, should be "Validity: 1w"? Wait, the text says "Validity: 1w"? Wait, no, looking again: "Validity: 1w"? Wait, the original text has "Validity: 1w"? Wait, let\'s check the user\'s image description.\n\nWait, the user provided the image description: "Ashley Hotel West Coast\\nWiFi Internet Service\\nUsername: fppp\\nPassword: aeeu\\nTraffic: 1 GB\\nPrice: 0.00\\nValidity: 1w\\nStarts: Now\\nShared Users: 4\\n27/02/2019 11:03:15\\nTo logout or check status please type in http://hello.wifi\\nThank you !"\n\nWait, but in the image, there might be typos. Let\'s parse each line.\n\nFirst line: Ashley Hotel West Coast (maybe typo, should be "Ashley Hotel West Coast"?)\n\nThen "WiFi Internet Service" (probably "WiFi Internet Service" with a typo, like "Servece" but user wrote "Service" in their text? Wait, no, in the user\'s input, it\'s "WiFi Internet Service" with correct spelling, but perhaps in the actual image it\'s "Servece"? Wait, no, the user\'s transcription says "WiFi Internet Service".\n\nWait, the user provided a transcript of the image: \n\n"Ashley Hotel West Coast\n\nWiFi Internet Service\n\nUsername: fppp\n\nPassword: aeeu\n\nTraffic: 1 GB\n\nPrice: 0.00\n\nValidity: 1w\n\nStarts: Now\n\nShared Users: 4\n\n27/02/2019 11:03:15\n\nTo logout or check status please type in http://hello.wifi\n\nThank you !"\n\nSo the image is a printed slip (probably on a piece of paper) that provides Wi-Fi network details for the Ashley Hotel West Coast. It includes:\n\n- Hotel name: Ashley Hotel West Coast\n\n- Service: WiFi Internet Service\n\n- Username: fppp\n\n- Password: aeeu\n\n- Traffic: 1 GB\n\n- Price: 0.00 (free?)\n\n- Validity: 1w (1 week?)\n\n- Starts: Now\n\n- Shared Users: 4\n\n- Date & time: 27/02/2019 11:03:15\n\n- Instruction to log out or check status: type in http://hello.wifi\n\n- Thank you note\n\nAlso, the background is a wooden surface, and the paper is slightly torn at the edges.\n\nNeed to describe what\'s in the image: the content of the slip, its purpose (Wi-Fi login info), details like username, password, traffic, price, validity, start time, shared users, timestamp, logout URL, and the background.\n', type='summary_text')], type='reasoning', content=[Content(text='So, let\'s look at the image. It\'s a printed receipt or a Wi-Fi information slip. The top says "Ashley Hotel West Coast" with a line. Then "WiFi Internet Service". Next, details: Username: fppp, Password: aeeu, Traffic: 1 GB, Price: 0.00, Validity: 1w (wait, maybe "Validity" is a typo, should be "Validity: 1w"? Wait, the text says "Validity: 1w"? Wait, no, looking again: "Validity: 1w"? Wait, the original text has "Validity: 1w"? Wait, let\'s check the user\'s image description.\n\nWait, the user provided the image description: "Ashley Hotel West Coast\\nWiFi Internet Service\\nUsername: fppp\\nPassword: aeeu\\nTraffic: 1 GB\\nPrice: 0.00\\nValidity: 1w\\nStarts: Now\\nShared Users: 4\\n27/02/2019 11:03:15\\nTo logout or check status please type in http://hello.wifi\\nThank you !"\n\nWait, but in the image, there might be typos. Let\'s parse each line.\n\nFirst line: Ashley Hotel West Coast (maybe typo, should be "Ashley Hotel West Coast"?)\n\nThen "WiFi Internet Service" (probably "WiFi Internet Service" with a typo, like "Servece" but user wrote "Service" in their text? Wait, no, in the user\'s input, it\'s "WiFi Internet Service" with correct spelling, but perhaps in the actual image  ...

# %% [markdown]
# ### Streaming response

# %%
response = client.responses.create(
    model="mlx-local-model",
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "what is in this image?"},
                {
                    "type": "input_image",
                    "image_url": "examples/images/password.jpg",
                    "detail": "low"
                }
            ]
        }
    ],
    stream=True
)

for chunk in response:
  print(chunk)
# Out:
# ResponseCreatedEvent(response=Response(id='resp_ea847c2767c142b6b87baa54c855d2fd', created_at=1771749070.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='in_progress', text=None, top_logprobs=None, truncation='disabled', usage=None, user=None), sequence_number=0, type='response.created')
# ResponseInProgressEvent(response=Response(id='resp_ea847c2767c142b6b87baa54c855d2fd', created_at=1771749070.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='in_progress', text=None, top_logprobs=None, truncation='disabled', usage=None, user=None), sequence_number=1, type='response.in_progress')
# ResponseOutputItemAddedEvent(item=ResponseReasoningItem(id='rs_ea847c2767c142b6b87baa54c855d2fd', summary=[], type='reasoning', content=None, encrypted_content=None, status='in_progress'), output_index=0, sequence_number=2, type='response.output_item.added')
# ResponseReasoningSummaryTextDeltaEvent(delta='So,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=3, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" let's", item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=4, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' look', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=5, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' at', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=6, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=7, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' image.', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=8, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" It's", item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=9, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=10, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' receipt', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=11, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' or', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=12, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=13, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' WiFi', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=14, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' access', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=15, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' slip', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=16, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' from', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=17, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Ashley', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=18, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Hotel', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=19, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' West', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=20, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Coast.', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=21, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" Let's", item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=22, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' list', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=23, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=24, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' details.\n\nFirst,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=25, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=26, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' header:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=27, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "Ashley', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=28, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Hotel', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=29, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' West', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=30, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Coast', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=31, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' WiFi', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=32, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Internet', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=33, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Service".', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=34, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Then', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=35, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=36, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' credentials:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=37, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Username', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=38, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=39, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' fcpp,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=40, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Password', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=41, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=42, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' aaeu.', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=43, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Traffic', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=44, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=45, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 1', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=46, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' GB,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=47, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Price', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=48, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=49, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 0.00', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=50, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (so', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=51, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' free?),', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=52, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Validity', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=53, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=54, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 1w', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=55, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (1', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=56, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' week),', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=57, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Starts:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=58, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Now', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=59, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (maybe', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=60, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=61, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' start', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=62, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' time?', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=63, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Wait,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=64, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' it', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=65, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' says', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=66, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "Starts:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=67, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Now"', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=68, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=69, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' then', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=70, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "Shared', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=71, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Users:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=72, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 4".', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=73, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Then', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=74, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" there's", item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=75, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=76, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' date', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=77, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=78, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' time:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=79, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 27/02/2019', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=80, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 11:03:15.', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=81, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Then', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=82, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' instructions:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=83, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "To', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=84, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' logout', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=85, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' or', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=86, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' check', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=87, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' status', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=88, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' please', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=89, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' type', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=90, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=91, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' http://hello.wifi', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=92, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Thank', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=93, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' you', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=94, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' !"\n\nWait,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=95, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' there', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=96, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' might', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=97, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' be', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=98, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=99, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' typo', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=100, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=101, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=102, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' original', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=103, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' image.', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=104, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Let', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=105, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' me', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=106, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' check', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=107, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=108, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' text', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=109, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' again.', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=110, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' The', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=111, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' image', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=112, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' shows', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=113, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "To', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=114, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' logout', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=115, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' or', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=116, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' check', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=117, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' status', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=118, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' please', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=119, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' type', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=120, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=121, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' http://hello.wifi', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=122, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Thank', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=123, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' you', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=124, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' !"', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=125, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' So', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=126, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" it's", item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=127, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=128, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' WiFi', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=129, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' login', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=130, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' slip', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=131, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' with', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=132, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' details', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=133, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' about', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=134, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=135, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" connection.\n\nLet's", item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=136, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' make', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=137, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' sure', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=138, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' to', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=139, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' parse', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=140, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' each', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=141, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' line:\n\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=142, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Hotel', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=143, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' name:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=144, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Ashley', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=145, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Hotel', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=146, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' West', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=147, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Coast\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=148, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Service:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=149, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' WiFi', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=150, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Internet', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=151, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Service\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=152, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Username:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=153, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' fcpp\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=154, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Password:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=155, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' aaeu\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=156, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Traffic:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=157, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 1', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=158, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' GB\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=159, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Price:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=160, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 0.00', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=161, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (so', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=162, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' no', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=163, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' cost)\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=164, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Validity:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=165, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 1w', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=166, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (probably', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=167, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 1', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=168, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' week)\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=169, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Starts:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=170, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Now', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=171, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (maybe', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=172, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=173, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' start', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=174, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' time', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=175, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' of', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=176, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=177, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' session)\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=178, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Shared', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=179, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Users:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=180, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 4', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=181, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (how', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=182, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' many', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=183, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' users', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=184, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' can', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=185, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' share)\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=186, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Date', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=187, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=188, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' time:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=189, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 27/02/2019', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=190, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' 11:03:15\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=191, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Logout/instruction:', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=192, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' To', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=193, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' logout', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=194, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' or', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=195, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' check', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=196, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' status,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=197, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' type', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=198, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' http://hello.wifi\n-', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=199, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Thank', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=200, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' you\n\nAlso,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=201, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=202, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' image', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=203, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' has', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=204, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=205, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' receipt-like', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=206, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' format', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=207, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' with', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=208, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' lines', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=209, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' under', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=210, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' some', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=211, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' titles,', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=212, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=213, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=214, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' background', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=215, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=216, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=217, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' wooden', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=218, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' surface.\n\nSo', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=219, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=220, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' image', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=221, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=222, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=223, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' WiFi', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=224, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' access', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=225, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' card', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=226, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' or', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=227, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' login', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=228, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' slip', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=229, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' from', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=230, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Ashley', item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=231, summary_index=0, type='response.reasoning_summary_text.delta')
# ...
# ResponseTextDeltaEvent(content_index=0, delta=' font', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=351, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=352, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' placed', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=353, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' on', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=354, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=355, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' dark', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=356, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' wooden', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=357, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' surface.', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=358, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' Some', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=359, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' minor', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=360, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' typos', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=361, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' (e.g.,', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=362, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' “Validity”', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=363, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' instead', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=364, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=365, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' “Validity,”', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=366, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' “logou”', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=367, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' instead', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=368, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=369, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' “logout”)', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=370, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' are', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=371, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' visible,', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=372, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' but', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=373, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=374, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' core', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=375, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' information', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=376, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' is', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=377, type='response.output_text.delta')
# ResponseTextDeltaEvent(content_index=0, delta=' clear.', item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=378, type='response.output_text.delta')
# ResponseReasoningSummaryTextDoneEvent(item_id='rs_ea847c2767c142b6b87baa54c855d2fd', output_index=0, sequence_number=379, summary_index=0, text='So, let\'s look at the image. It\'s a receipt or a WiFi access slip from Ashley Hotel West Coast. Let\'s list the details.\n\nFirst, the header: "Ashley Hotel West Coast WiFi Internet Service". Then the credentials: Username is fcpp, Password is aaeu. Traffic is 1 GB, Price is 0.00 (so free?), Validity is 1w (1 week), Starts: Now (maybe the start time? Wait, it says "Starts: Now" and then "Shared Users: 4". Then there\'s a date and time: 27/02/2019 11:03:15. Then instructions: "To logout or check status please type in http://hello.wifi Thank you !"\n\nWait, there might be a typo in the original image. Let me check the text again. The image shows "To logout or check status please type in http://hello.wifi Thank you !" So it\'s a WiFi login slip with details about the connection.\n\nLet\'s make sure to parse each line:\n\n- Hotel name: Ashley Hotel West Coast\n- Service: WiFi Internet Service\n- Username: fcpp\n- Password: aaeu\n- Traffic: 1 GB\n- Price: 0.00 (so no cost)\n- Validity: 1w (probably 1 week)\n- Starts: Now (maybe the start time of the session)\n- Shared Users: 4 (how many users can share)\n- Date and time: 27/02/2019 11:03:15\n- Logout/instruction: To logout or check status, type http://hello.wifi\n- Thank you\n\nAlso, the image has a receipt-like format with lines under some titles, and the background is a wooden surface.\n\nSo the image is a WiFi access card or login slip from Ashley Hotel West Coast, containing login credentials, session details, and instructions.\n', type='response.reasoning_summary_text.done')
# ResponseOutputItemDoneEvent(item=ResponseReasoningItem(id='rs_ea847c2767c142b6b87baa54c855d2fd', summary=[Summary(text='So, let\'s look at the image. It\'s a receipt or a WiFi access slip from Ashley Hotel West Coast. Let\'s list the details.\n\nFirst, the header: "Ashley Hotel West Coast WiFi Internet Service". Then the credentials: Username is fcpp, Password is aaeu. Traffic is 1 GB, Price is 0.00 (so free?), Validity is 1w (1 week), Starts: Now (maybe the start time? Wait, it says "Starts: Now" and then "Shared Users: 4". Then there\'s a date and time: 27/02/2019 11:03:15. Then instructions: "To logout or check status please type in http://hello.wifi Thank you !"\n\nWait, there might be a typo in the original image. Let me check the text again. The image shows "To logout or check status please type in http://hello.wifi Thank you !" So it\'s a WiFi login slip with details about the connection.\n\nLet\'s make sure to parse each line:\n\n- Hotel name: Ashley Hotel West Coast\n- Service: WiFi Internet Service\n- Username: fcpp\n- Password: aaeu\n- Traffic: 1 GB\n- Price: 0.00 (so no cost)\n- Validity: 1w (probably 1 week)\n- Starts: Now (maybe the start time of the session)\n- Shared Users: 4 (how many users can share)\n- Date and time: 27/02/2019 11:03:15\n- Logout/instruction: To logout or check status, type http://hello.wifi\n- Thank you\n\nAlso, the image has a receipt-like format with lines under some titles, and the background is a wooden surface.\n\nSo the image is a WiFi access card or login slip from Ashley Hotel West Coast, containing login credentials, session details, and instructions.\n', type='summary_text')], type='reasoning', content=None, encrypted_content=None, status='completed'), output_index=0, sequence_number=380, type='response.output_item.done')
# ResponseTextDoneEvent(content_index=0, item_id='msg_ea847c2767c142b6b87baa54c855d2fd', logprobs=[], output_index=1, sequence_number=381, text='\n\nThe image is a **WiFi access slip** from **Ashley Hotel West Coast**. Here’s the detailed information it contains:  \n\n- **Hotel/Service**: *Ashley Hotel West Coast WiFi Internet Service*  \n- **Credentials**:  \n  - Username: `fccp`  \n  - Password: `aaeu`  \n- **Connection Details**:  \n  - Traffic: 1 GB  \n  - Price: 0.00 (free service)  \n  - Validity: 1w (likely 1 week)  \n  - Starts: *Now*  \n  - Shared Users: 4  \n- **Session Timestamp**: *27/02/2019 11:03:15*  \n- **Logout/Status Instruction**: *“To logout or check status please type in http://hello.wifi”*  \n- **Closing**: *“Thank you !”*  \n\nThe slip is printed on a light-colored paper with a handwritten-style font and placed on a dark wooden surface. Some minor typos (e.g., “Validity” instead of “Validity,” “logou” instead of “logout”) are visible, but the core information is clear.', type='response.output_text.done')
# ResponseContentPartDoneEvent(content_index=0, item_id='msg_ea847c2767c142b6b87baa54c855d2fd', output_index=1, part=ResponseOutputText(annotations=[], text='\n\nThe image is a **WiFi access slip** from **Ashley Hotel West Coast**. Here’s the detailed information it contains:  \n\n- **Hotel/Service**: *Ashley Hotel West Coast WiFi Internet Service*  \n- **Credentials**:  \n  - Username: `fccp`  \n  - Password: `aaeu`  \n- **Connection Details**:  \n  - Traffic: 1 GB  \n  - Price: 0.00 (free service)  \n  - Validity: 1w (likely 1 week)  \n  - Starts: *Now*  \n  - Shared Users: 4  \n- **Session Timestamp**: *27/02/2019 11:03:15*  \n- **Logout/Status Instruction**: *“To logout or check status please type in http://hello.wifi”*  \n- **Closing**: *“Thank you !”*  \n\nThe slip is printed on a light-colored paper with a handwritten-style font and placed on a dark wooden surface. Some minor typos (e.g., “Validity” instead of “Validity,” “logou” instead of “logout”) are visible, but the core information is clear.', type='output_text', logprobs=None), sequence_number=382, type='response.content_part.done')
# ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_ea847c2767c142b6b87baa54c855d2fd', content=[ResponseOutputText(annotations=[], text='\n\nThe image is a **WiFi access slip** from **Ashley Hotel West Coast**. Here’s the detailed information it contains:  \n\n- **Hotel/Service**: *Ashley Hotel West Coast WiFi Internet Service*  \n- **Credentials**:  \n  - Username: `fccp`  \n  - Password: `aaeu`  \n- **Connection Details**:  \n  - Traffic: 1 GB  \n  - Price: 0.00 (free service)  \n  - Validity: 1w (likely 1 week)  \n  - Starts: *Now*  \n  - Shared Users: 4  \n- **Session Timestamp**: *27/02/2019 11:03:15*  \n- **Logout/Status Instruction**: *“To logout or check status please type in http://hello.wifi”*  \n- **Closing**: *“Thank you !”*  \n\nThe slip is printed on a light-colored paper with a handwritten-style font and placed on a dark wooden surface. Some minor typos (e.g., “Validity” instead of “Validity,” “logou” instead of “logout”) are visible, but the core information is clear.', type='output_text', logprobs=None)], role='assistant', status='completed', type='message', summary=[]), output_index=1, sequence_number=383, type='response.output_item.done')
# ResponseCompletedEvent(response=Response(id='resp_ea847c2767c142b6b87baa54c855d2fd', created_at=1771749070.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[ResponseReasoningItem(id='rs_ea847c2767c142b6b87baa54c855d2fd', summary=[Summary(text='So, let\'s look at the image. It\'s a receipt or a WiFi access slip from Ashley Hotel West Coast. Let\'s list the details.\n\nFirst, the header: "Ashley Hotel West Coast WiFi Internet Service". Then the credentials: Username is fcpp, Password is aaeu. Traffic is 1 GB, Price is 0.00 (so free?), Validity is 1w (1 week), Starts: Now (maybe the start time? Wait, it says "Starts: Now" and then "Shared Users: 4". Then there\'s a date and time: 27/02/2019 11:03:15. Then instructions: "To logout or check status please type in http://hello.wifi Thank you !"\n\nWait, there might be a typo in the original image. Let me check the text again. The image shows "To logout or check status please type in http://hello.wifi Thank you !" So it\'s a WiFi login slip with details about the connection.\n\nLet\'s make sure to parse each line:\n\n- Hotel name: Ashley Hotel West Coast\n- Service: WiFi Internet Service\n- Username: fcpp\n- Password: aaeu\n- Traffic: 1 GB\n- Price: 0.00 (so no cost)\n- Validity: 1w (probably 1 week)\n- Starts: Now (maybe the start time of the session)\n- Shared Users: 4 (how many users can share)\n- Date and time: 27/02/2019 11:03:15\n- Logout/instruction: To logout or check status, type http://hello.wifi\n- Thank you\n\nAlso, the image has a receipt-like format with lines under some titles, and the background is a wooden surface.\n\nSo the image is a WiFi access card or login slip from Ashley Hotel West Coast, containing login credentials, session details, and instructions.\n', type='summary_text')], type='reasoning', content=None, encrypted_content=None, status='completed'), ResponseOutputMessage(id='msg_ea847c2767c142b6b87baa54c855d2fd', content=[ResponseOutputText(annotations=[], text='\n\nThe image is a **WiFi access slip** from **Ashley Hotel West Coast**. Here’s the detailed information it contains:  \n\n- **Hotel/Service**: *Ashley Hotel West Coast WiFi Internet Service*  \n- **Credentials**:  \n  - Username: `fccp`  \n  - Password: `aaeu`  \n- **Connection Details**:  \n  - Traffic: 1 GB  \n  - Price: 0.00 (free service)  \n  - Validity: 1w (likely 1 week)  \n  - Starts: *Now*  \n  - Shared Users: 4  \n- **Session Timestamp**: *27/02/2019 11:03:15*  \n- **Logout/Status Instruction**: *“To logout or check status please type in http://hello.wifi”*  \n- **Closing**: *“Thank you !”*  \n\nThe slip is printed on a light-colored paper with a handwritten-style font and placed on a dark wooden surface. Some minor typos (e.g., “Validity” instead of “Validity,” “logou” instead of “logout”) are visible, but the core information is clear.', type='output_text', logprobs=None)], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='completed', text=None, top_logprobs=None, truncation='disabled', usage=ResponseUsage(input_tokens=158, input_tokens_details=InputTokensDetails(cached_tokens=0, input_tokens_per_turn=[], cached_tokens_per_turn=[]), output_tokens=663, output_tokens_details=OutputTokensDetails(reasoning_tokens=0, tool_output_tokens=0, output_tokens_per_turn=[], tool_output_tokens_per_turn=[]), total_tokens=821), user=None), sequence_number=384, type='response.completed')

# %% [markdown]
# ## Functions

# %%
tools = [
    {
        "type": "function",
        "name": "get_current_weather",
        "description": "Get the current weather in a given location",
        "parameters": {
          "type": "object",
          "properties": {
              "location": {
                  "type": "string",
                  "description": "The city and state, e.g. San Francisco, CA",
              },
              "unit": {"type": "string", "enum": ["celsius", "fahrenheit"]},
          },
          "required": ["location", "unit"],
        }
    }
]

# %% [markdown]
# ### Non-streaming response

# %%
response = client.responses.create(
  model="mlx-local-model",
  tools=tools,
  input="What is the weather like in Boston today?",
  tool_choice="auto"
)

print(response)
# Out:
# Response(id='resp_d603c021b0b34922b428c496496ba285', created_at=1771749176.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[ResponseReasoningItem(id='rs_d603c021b0b34922b428c496496ba285', summary=[Summary(text='Okay, the user is asking about the weather in Boston today. Let me check the tools available. There\'s a function called get_current_weather that takes location and unit as parameters. The location needs to be a city and state, like "San Francisco, CA". The user mentioned Boston, but didn\'t specify the state. Wait, Boston is in Massachusetts, so the location should be "Boston, MA". The unit parameter is required and has to be either celsius or fahrenheit. Since the user didn\'t specify, maybe I should default to a common one. In the US, people usually use Fahrenheit, but sometimes people might expect Celsius. Hmm, but the question is in English, so probably Fahrenheit. Let me check the tool\'s required parameters: both location and unit are required. So I need to include both. The user said "today", so current weather. Let me structure the function call with location "Boston, MA" and unit "fahrenheit". Wait, but the user didn\'t specify the unit. The tool requires it, so I have to pick one. Maybe safest to use fahrenheit since it\'s the US standard. Let me make the call with that.\n', type='summary_text')], type='reasoning', content=[Content(text='Okay, the user is asking about the weather in Boston today. Let me check the tools available. There\'s a function called get_current_weather that takes location and unit as parameters. The location needs to be a city and state, like "San Francisco, CA". The user mentioned Boston, but didn\'t specify the state. Wait, Boston is in Massachusetts, so the location should be "Boston, MA". The unit parameter is required and has to be either celsius or fahrenheit. Since the user didn\'t specify, maybe I should default to a common one. In the US, people usually use Fahrenheit, but sometimes people might expect Celsius. Hmm, but the question is in English, so probably Fahrenheit. Let me check the tool\'s required parameters: both location and unit are required. So I need to include both. The user said "today", so current weather. Let me structure the function call with location "Boston, MA" and unit "fahrenheit". Wait, but the user didn\'t specify the unit. The tool requires it, so I have to pick one. Maybe safest to use fahrenheit since it\'s the US standard. Let me make the call with that.\n', type='reasoning_text')], encrypted_content=None, status='completed'), ResponseFunctionToolCall(arguments='{"location": "Boston, MA", "unit": "fahrenheit"}', call_id='call_d603c021b0b34922b428c496496ba285_0', name='get_current_weather', type='function_call', id='fc_d603c021b0b34922b428c496496ba285_0', status='completed')], parallel_tool_calls=None, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='get_current_weather', parameters={'type': 'object', 'properties': {'location': {'type': 'string', 'description': 'The city and state, e.g. San Francisco, CA'}, 'unit': {'type': 'string', 'enum': ['celsius', 'fahrenheit']}}, 'required': ['location', 'unit']}, strict=None, type='function', description='Get the current weather in a given location')], top_p=1.0, background=None, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier=None, status='completed', text=None, top_logprobs=None, truncation=None, usage=ResponseUsage(input_tokens=201, input_tokens_details=InputTokensDetails(cached_tokens=0, input_tokens_per_turn=[], cached_tokens_per_turn=[]), output_tokens=271, output_tokens_details=OutputTokensDetails(reasoning_tokens=0, tool_output_tokens=0, output_tokens_per_turn=[], tool_output_tokens_per_turn=[]), total_tokens=472), user=None)

# %% [markdown]
# ### Streaming response

# %%
response = client.responses.create(
  model="mlx-local-model",
  tools=tools,
  input="What is the weather like in Boston today?",
  tool_choice="auto",
  stream=True
)

for chunk in response:
  print(chunk)
# Out:
# ResponseCreatedEvent(response=Response(id='resp_4670d32e8fef4e33af3b2e6732428865', created_at=1771749186.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='get_current_weather', parameters={'type': 'object', 'properties': {'location': {'type': 'string', 'description': 'The city and state, e.g. San Francisco, CA'}, 'unit': {'type': 'string', 'enum': ['celsius', 'fahrenheit']}}, 'required': ['location', 'unit']}, strict=None, type='function', description='Get the current weather in a given location')], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='in_progress', text=None, top_logprobs=None, truncation='disabled', usage=None, user=None), sequence_number=0, type='response.created')
# ResponseInProgressEvent(response=Response(id='resp_4670d32e8fef4e33af3b2e6732428865', created_at=1771749186.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='get_current_weather', parameters={'type': 'object', 'properties': {'location': {'type': 'string', 'description': 'The city and state, e.g. San Francisco, CA'}, 'unit': {'type': 'string', 'enum': ['celsius', 'fahrenheit']}}, 'required': ['location', 'unit']}, strict=None, type='function', description='Get the current weather in a given location')], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='in_progress', text=None, top_logprobs=None, truncation='disabled', usage=None, user=None), sequence_number=1, type='response.in_progress')
# ResponseOutputItemAddedEvent(item=ResponseReasoningItem(id='rs_4670d32e8fef4e33af3b2e6732428865', summary=[], type='reasoning', content=None, encrypted_content=None, status='in_progress'), output_index=0, sequence_number=2, type='response.output_item.added')
# ResponseReasoningSummaryTextDeltaEvent(delta='Okay,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=3, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=4, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' user', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=5, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=6, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' asking', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=7, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' about', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=8, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=9, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' weather', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=10, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=11, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Boston', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=12, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' today.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=13, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Let', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=14, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' me', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=15, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' check', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=16, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=17, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' tools', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=18, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' provided.\n\nLooking', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=19, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' at', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=20, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=21, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' tools', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=22, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' section,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=23, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" there's", item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=24, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=25, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' function', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=26, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' called', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=27, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' get_current_weather.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=28, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' It', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=29, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' requires', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=30, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' location', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=31, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=32, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unit.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=33, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' The', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=34, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' location', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=35, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' should', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=36, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' be', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=37, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' a', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=38, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' city', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=39, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=40, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' state,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=41, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' like', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=42, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "San', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=43, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Francisco,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=44, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' CA".', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=45, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' The', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=46, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' user', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=47, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' mentioned', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=48, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Boston,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=49, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' but', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=50, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' they', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=51, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" didn't", item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=52, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' specify', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=53, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=54, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' state.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=55, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Wait,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=56, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Boston', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=57, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=58, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=59, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Massachusetts,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=60, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' so', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=61, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=62, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' location', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=63, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' parameter', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=64, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' should', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=65, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' probably', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=66, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' be', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=67, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "Boston,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=68, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' MA".\n\nThe', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=69, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unit', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=70, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=71, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' an', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=72, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' enum', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=73, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' with', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=74, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' celsius', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=75, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' or', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=76, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' fahrenheit.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=77, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' The', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=78, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' user', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=79, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" didn't", item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=80, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' specify,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=81, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' but', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=82, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' since', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=83, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" they're", item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=84, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' asking', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=85, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' about', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=86, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=87, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' weather', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=88, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' today,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=89, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' maybe', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=90, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' they', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=91, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' expect', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=92, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=93, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' default', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=94, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unit', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=95, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' used', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=96, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=97, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=98, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' US,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=99, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' which', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=100, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=101, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Fahrenheit.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=102, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' However,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=103, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=104, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' function', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=105, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' requires', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=106, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' it', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=107, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' to', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=108, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' be', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=109, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' specified.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=110, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Hmm,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=111, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' but', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=112, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=113, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' user', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=114, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=" didn't", item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=115, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' say', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=116, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' anything', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=117, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' about', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=118, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' units.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=119, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Should', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=120, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' I', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=121, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' assume', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=122, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' US', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=123, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' units?', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=124, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Maybe', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=125, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=126, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=127, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' response,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=128, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' I', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=129, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' should', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=130, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' include', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=131, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=132, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unit', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=133, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' as', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=134, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' fahrenheit.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=135, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Wait,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=136, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' but', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=137, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=138, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' function', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=139, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' requires', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=140, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' it.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=141, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' So', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=142, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' I', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=143, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' need', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=144, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' to', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=145, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' include', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=146, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=147, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unit', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=148, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=149, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=150, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' tool', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=151, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' call.\n\nWait,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=152, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=153, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' required', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=154, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' parameters', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=155, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' for', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=156, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=157, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' function', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=158, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' are', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=159, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' location', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=160, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' and', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=161, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unit.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=162, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' So', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=163, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' I', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=164, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' have', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=165, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' to', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=166, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' provide', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=167, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' both.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=168, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Since', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=169, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=170, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' user', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=171, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=172, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' in', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=173, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=174, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' US', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=175, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' (Boston),', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=176, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' they', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=177, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' probably', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=178, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' want', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=179, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Fahrenheit.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=180, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' So', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=181, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=182, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' arguments', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=183, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' would', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=184, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' be', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=185, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' location:', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=186, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "Boston,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=187, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' MA",', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=188, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' unit:', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=189, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' "fahrenheit".\n\nI', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=190, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' should', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=191, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' structure', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=192, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=193, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' tool', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=194, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' call', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=195, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' accordingly.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=196, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Let', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=197, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' me', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=198, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' make', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=199, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' sure', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=200, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=201, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' location', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=202, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=203, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' correctly', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=204, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' formatted', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=205, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' as', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=206, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' city,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=207, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' state.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=208, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' Boston,', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=209, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' MA', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=210, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' is', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=211, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' correct.', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=212, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' So', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=213, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' the', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=214, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' tool', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=215, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' call', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=216, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' should', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=217, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' have', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=218, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' those', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=219, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseReasoningSummaryTextDeltaEvent(delta=' parameters.\n', item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=220, summary_index=0, type='response.reasoning_summary_text.delta')
# ResponseOutputItemAddedEvent(item=ResponseFunctionToolCall(arguments='', call_id='call_1771749192641348', name='get_current_weather', type='function_call', id='fc_4670d32e8fef4e33af3b2e6732428865_0', status='in_progress'), output_index=1, sequence_number=221, type='response.output_item.added')
# ResponseFunctionCallArgumentsDeltaEvent(delta='{"location": "Boston, MA", "unit": "fahrenheit"}', item_id='fc_4670d32e8fef4e33af3b2e6732428865_0', output_index=1, sequence_number=222, type='response.function_call_arguments.delta')
# ResponseReasoningSummaryTextDoneEvent(item_id='rs_4670d32e8fef4e33af3b2e6732428865', output_index=0, sequence_number=223, summary_index=0, text='Okay, the user is asking about the weather in Boston today. Let me check the tools provided.\n\nLooking at the tools section, there\'s a function called get_current_weather. It requires location and unit. The location should be a city and state, like "San Francisco, CA". The user mentioned Boston, but they didn\'t specify the state. Wait, Boston is in Massachusetts, so the location parameter should probably be "Boston, MA".\n\nThe unit is an enum with celsius or fahrenheit. The user didn\'t specify, but since they\'re asking about the weather today, maybe they expect the default unit used in the US, which is Fahrenheit. However, the function requires it to be specified. Hmm, but the user didn\'t say anything about units. Should I assume US units? Maybe in the response, I should include the unit as fahrenheit. Wait, but the function requires it. So I need to include the unit in the tool call.\n\nWait, the required parameters for the function are location and unit. So I have to provide both. Since the user is in the US (Boston), they probably want Fahrenheit. So the arguments would be location: "Boston, MA", unit: "fahrenheit".\n\nI should structure the tool call accordingly. Let me make sure the location is correctly formatted as city, state. Boston, MA is correct. So the tool call should have those parameters.\n', type='response.reasoning_summary_text.done')
# ResponseOutputItemDoneEvent(item=ResponseReasoningItem(id='rs_4670d32e8fef4e33af3b2e6732428865', summary=[Summary(text='Okay, the user is asking about the weather in Boston today. Let me check the tools provided.\n\nLooking at the tools section, there\'s a function called get_current_weather. It requires location and unit. The location should be a city and state, like "San Francisco, CA". The user mentioned Boston, but they didn\'t specify the state. Wait, Boston is in Massachusetts, so the location parameter should probably be "Boston, MA".\n\nThe unit is an enum with celsius or fahrenheit. The user didn\'t specify, but since they\'re asking about the weather today, maybe they expect the default unit used in the US, which is Fahrenheit. However, the function requires it to be specified. Hmm, but the user didn\'t say anything about units. Should I assume US units? Maybe in the response, I should include the unit as fahrenheit. Wait, but the function requires it. So I need to include the unit in the tool call.\n\nWait, the required parameters for the function are location and unit. So I have to provide both. Since the user is in the US (Boston), they probably want Fahrenheit. So the arguments would be location: "Boston, MA", unit: "fahrenheit".\n\nI should structure the tool call accordingly. Let me make sure the location is correctly formatted as city, state. Boston, MA is correct. So the tool call should have those parameters.\n', type='summary_text')], type='reasoning', content=None, encrypted_content=None, status='completed'), output_index=0, sequence_number=224, type='response.output_item.done')
# ResponseFunctionCallArgumentsDoneEvent(arguments='{"location": "Boston, MA", "unit": "fahrenheit"}', item_id='fc_4670d32e8fef4e33af3b2e6732428865_0', name=None, output_index=1, sequence_number=225, type='response.function_call_arguments.done')
# ResponseOutputItemDoneEvent(item=ResponseFunctionToolCall(arguments='{"location": "Boston, MA", "unit": "fahrenheit"}', call_id=None, name='get_current_weather', type='function_call', id='fc_4670d32e8fef4e33af3b2e6732428865_0', status='completed'), output_index=1, sequence_number=226, type='response.output_item.done')
# ResponseCompletedEvent(response=Response(id='resp_4670d32e8fef4e33af3b2e6732428865', created_at=1771749186.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='mlx-local-model', object='response', output=[ResponseReasoningItem(id='rs_4670d32e8fef4e33af3b2e6732428865', summary=[Summary(text='Okay, the user is asking about the weather in Boston today. Let me check the tools provided.\n\nLooking at the tools section, there\'s a function called get_current_weather. It requires location and unit. The location should be a city and state, like "San Francisco, CA". The user mentioned Boston, but they didn\'t specify the state. Wait, Boston is in Massachusetts, so the location parameter should probably be "Boston, MA".\n\nThe unit is an enum with celsius or fahrenheit. The user didn\'t specify, but since they\'re asking about the weather today, maybe they expect the default unit used in the US, which is Fahrenheit. However, the function requires it to be specified. Hmm, but the user didn\'t say anything about units. Should I assume US units? Maybe in the response, I should include the unit as fahrenheit. Wait, but the function requires it. So I need to include the unit in the tool call.\n\nWait, the required parameters for the function are location and unit. So I have to provide both. Since the user is in the US (Boston), they probably want Fahrenheit. So the arguments would be location: "Boston, MA", unit: "fahrenheit".\n\nI should structure the tool call accordingly. Let me make sure the location is correctly formatted as city, state. Boston, MA is correct. So the tool call should have those parameters.\n', type='summary_text')], type='reasoning', content=None, encrypted_content=None, status='completed'), ResponseFunctionToolCall(arguments='{"location": "Boston, MA", "unit": "fahrenheit"}', call_id=None, name='get_current_weather', type='function_call', id='fc_4670d32e8fef4e33af3b2e6732428865_0', status='completed')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='get_current_weather', parameters={'type': 'object', 'properties': {'location': {'type': 'string', 'description': 'The city and state, e.g. San Francisco, CA'}, 'unit': {'type': 'string', 'enum': ['celsius', 'fahrenheit']}}, 'required': ['location', 'unit']}, strict=None, type='function', description='Get the current weather in a given location')], top_p=1.0, background=False, conversation=None, max_output_tokens=100000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='auto', status='completed', text=None, top_logprobs=None, truncation='disabled', usage=ResponseUsage(input_tokens=201, input_tokens_details=InputTokensDetails(cached_tokens=0, input_tokens_per_turn=[], cached_tokens_per_turn=[]), output_tokens=316, output_tokens_details=OutputTokensDetails(reasoning_tokens=0, tool_output_tokens=0, output_tokens_per_turn=[], tool_output_tokens_per_turn=[]), total_tokens=517), user=None), sequence_number=227, type='response.completed')

# %% [markdown]
# ## Structured Outputs

# %%
from pydantic import BaseModel

# %%
class Address(BaseModel):
    street: str
    city: str
    state: str
    zip: str

response = client.responses.parse(
    model="mlx-local-model",
    input=[
        {
            "role": "system",
            "content": "You are an assistant that can answer questions and help with tasks."
        },
        {"role": "user", "content": "Format: 1 Hacker Wy Menlo Park CA 94025"}
    ],
    text_format=Address,
)

address = response.output_parsed

print(address)
# Out:
# street='1 Hacker Wy' city='Menlo Park' state='CA' zip='94025'
